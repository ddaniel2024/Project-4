# %%
# Import the dependencies.
import pandas as pd
import psycopg2

# %%
# Establish the connection
conn = psycopg2.connect(
   database="project_4", user="postgres", password="postgres", host="localhost", port="5432"
)

# Create dataframe
df = pd.read_sql_query('''SELECT * from attrition WHERE age = 41''', conn)

# Close the connection
conn.close()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_19712\3057932573.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('''SELECT * from attrition WHERE age = 41''', conn)

# %%
df
# Out:
#     age attrition     businesstravel  dailyrate              department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    41       Yes      Travel_Rarely       1360  Research & Development
# 2    41        No      Travel_Rarely        802                   Sales
# 3    41        No  Travel_Frequently        857  Research & Development
# 4    41        No      Travel_Rarely        933  Research & Development
# 5    41        No      Travel_Rarely        465  Research & Development
# 6    41       Yes      Travel_Rarely       1356                   Sales
# 7    41        No      Travel_Rarely        896                   Sales
# 8    41        No      Travel_Rarely       1411  Research & Development
# 9    41        No      Travel_Rarely        334                   Sales
# 10   41        No      Travel_Rarely        483  Research & Development
# 11   41       Yes  Travel_Frequently        143                   Sales
# ...
